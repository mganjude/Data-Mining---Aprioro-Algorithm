# %% [markdown]
# ### Student Details
# Student Details
# Student Name and ID: Mehul Deorao Ganjude, 1001990551
#
# Team member name and ID: Venkata Nagendar Shantiswaroop Adibhatla 1001862413
#
# Team member name and ID: Gagan Ujjini Mallikarjuna 1001851247

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
# return false;
# }

# %%
# Import your Libraries
import pandas as pd
from pandas import DataFrame
import csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import apriori
from apriori import getItemSetTransactionList
from apriori import returnItemsWithMinSupport
#from mlxtend.preprocessing import TransactionEncoder
#from mlxtend.frequent_patterns import fpgrowth
from apriori import runApriori
from apriori import printResults
from apriori import dataFromFile
from apriori import joinSet
from apriori import subsets
from IPython.display import Image
# Above are the only libraries you can use. Do not make any changes above.
# -10 will be deducted, if you use additional libraries apart from these.

# %%
df=pd.read_csv("Groceries_dataset.csv")
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552    5/1/2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12/12/2015       other vegetables
# 4               3037    1/2/2015             whole milk
# ...              ...         ...                    ...
# 38760           4471   8/10/2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510   3/12/2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
# Checking for Null value if any:- 
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Task 1: DataSet Preprocess

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
# read the file and convert to dataframe
df=pd.read_csv("Groceries_dataset.csv")
df=df.drop_duplicates()
c=list(df.columns)
#grouped=df.groupby(c[0:2])
data_grouped=df.groupby(['Member_number','Date'])['itemDescription'].apply(lambda x: ','.join(x)).reset_index()
#data_grouped=grouped.aggregate(','.join)['itemDescription']
data_grouped
# Out:
#        Member_number        Date  \
# 0               1000  15-03-2015
# 1               1000  24-06-2014
# 2               1000  24-07-2015
# 3               1000  25-11-2015
# 4               1000  27-05-2015
# ...              ...         ...
# 14958           4999  26-12-2015
# 14959           4999    9/4/2014
# 14960           5000   10/2/2015
# 14961           5000  16-11-2014
# 14962           5000    9/3/2014
#
#                                      itemDescription
# 0      sausage,whole milk,semi-finished bread,yogurt
# 1                      whole milk,pastry,salty snack
# 2                        canned beer,misc. beverages
# 3                           sausage,hygiene articles
# 4                            soda,pickled vegetables
# ...                                              ...
# 14958                            bottled water,herbs
# 14959                 semi-finished bread,newspapers
# 14960       soda,root vegetables,semi-finished bread
# ...

# %%
df=pd.read_csv("Groceries_dataset.csv")
df=df.drop_duplicates()
c=list(df.columns)
grouped=df.groupby(c[0:2])
data_grouped=df.groupby(['Member_number','Date'])['itemDescription'].apply(lambda x: ','.join(x)).reset_index()
data_grouped=grouped.aggregate(','.join)['itemDescription']
data_grouped.to_csv('dataset.csv',index=False)
df1=pd.read_csv('dataset.csv')
df1
# Out:
#                                      itemDescription
# 0      sausage,whole milk,semi-finished bread,yogurt
# 1                      whole milk,pastry,salty snack
# 2                        canned beer,misc. beverages
# 3                           sausage,hygiene articles
# 4                            soda,pickled vegetables
# ...                                              ...
# 14958                            bottled water,herbs
# 14959                 semi-finished bread,newspapers
# 14960       soda,root vegetables,semi-finished bread
# 14961                  bottled beer,other vegetables
# 14962                   fruit/vegetable juice,onions
#
# [14963 rows x 1 columns]

# %%
# dataSet=[]
# for i in data_grouped:
#     dataSet.append(i)
# dataSet

# %%
# df1=pd.read_csv("dataset.csv")
# df1

# %%
# # #	Solution	# # #
df1.head(7)
# Out:
#                                  itemDescription
# 0  sausage,whole milk,semi-finished bread,yogurt
# 1                  whole milk,pastry,salty snack
# 2                    canned beer,misc. beverages
# 3                       sausage,hygiene articles
# 4                        soda,pickled vegetables
# 5                                whole milk,soda
# 6                               beef,white bread

# %% [markdown]
# ### Task 2: Run apriory.py and Evaluate Results

# %%
# ###### print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #\n')
inputTransactions = apriori.dataFromFile('dataset.csv')
print ('Case 1 (minimum support = 0.003 and minimum confidence = 0.05)\n')
print ('Case 1 Reasoning:')
print('\nThe rules must have higher confidence value and confidence value is greater than support value.')
print('\nIf support is greater than confidence, rules will be misleading as the chance of having an item reduces the chance of having another item in transaction.The lower the support value, higher the number of itemlists generated.')
print('\nHere,minimum support is chosen as 0.3% and minimum confidence is chosen as 5%.Minimum support is 0.3% because when we consider lower values for support,the transaction frequency is almost same, and 0.3% gave more appropriate itemsets. The confidence is 5% which means, if one item is already in the basket, there is 5% chance that other item  is also added to the basket.') 
# !python apriori.py -f dataset.csv -s 0.003 -c 0.05
# Out:
# Case 1 (minimum support = 0.003 and minimum confidence = 0.05)
#
# Case 1 Reasoning:
#
# The rules must have higher confidence value and confidence value is greater than support value.
#
# If support is greater than confidence, rules will be misleading as the chance of having an item reduces the chance of having another item in transaction.The lower the support value, higher the number of itemlists generated.
#
# Here,minimum support is chosen as 0.3% and minimum confidence is chosen as 5%.Minimum support is 0.3% because when we consider lower values for support,the transaction frequency is almost same, and 0.3% gave more appropriate itemsets. The confidence is 5% which means, if one item is already in the basket, there is 5% chance that other item  is also added to the basket.
#
# ------------ITEMS-----------------
# item: ('"candy',) , 0.003
# item: ('"chewing gum',) , 0.003
# item: ('whole milk', '"sausage') , 0.003
# item: ('cling film/bags"',) , 0.003
# item: ('pork"',) , 0.003
# ...

# %%
###### print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #\n')
inputTransactions = apriori.dataFromFile('dataset.csv')
items, rules = apriori.runApriori(inputTransactions,0.002,0.04)
print ('Case 2 (minimum support = 0.002 and minimum confidence = 0.04)\n')
print ('Case 2 Reasoning:')
print('\nIn this, minimum support value and minimum confidence are decreased.')
print('\nAs the minimum support is decreased, the chance of selecting more items of an item set in the basket is improved. The number of itemsets generated here is more (we can see that number of itemsets increased from the previous scenario).')
print('\nHere,minimum support is chosen as 0.2% and minimum confidence is chosen as 4%.Minimum support is 0.2% because when we consider lower values for support,the transaction frequency is almost same, and 0.2% gave more appropriate itemsets. The confidence is 4% which means, if one item is already in the basket, there is 4% chance that other item  is also added to the basket.') 
printResults(items,rules)
# Out:
# Case 2 (minimum support = 0.002 and minimum confidence = 0.04)
#
# Case 2 Reasoning:
#
# In this, minimum support value and minimum confidence are decreased.
#
# As the minimum support is decreased, the chance of selecting more items of an item set in the basket is improved. The number of itemsets generated here is more (we can see that number of itemsets increased from the previous scenario).
#
# Here,minimum support is chosen as 0.2% and minimum confidence is chosen as 4%.Minimum support is 0.2% because when we consider lower values for support,the transaction frequency is almost same, and 0.2% gave more appropriate itemsets. The confidence is 4% which means, if one item is already in the basket, there is 4% chance that other item  is also added to the basket.
#
# ------------ITEMS-----------------
# item: ('dishes',) , 0.002
# item: ('"processed cheese',) , 0.002
# item: ('rice"',) , 0.002
# item: ('rolls/buns"', '"frankfurter') , 0.002
# ...

# %%
###### print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #\n')
inputTransactions = apriori.dataFromFile('dataset.csv')
items, rules = apriori.runApriori(inputTransactions,0.001,0.03)
print ('Case 3 (minimum support = 0.001 and minimum confidence = 0.03)\n')
print ('Case 3 Reasoning:')
print('\nIn this minimum support value is decreased further to 0.1% and minimum confidence is decreased to 3%.')
print('\nAs we further decrease the minimum support value the number of itemsets will be more. As the minumum confidence   value is decreased,the number of rules obtained increases considerably improves the possibility of an transaction of an item.')
print('\nHence it can be said that as the confidence value increases, the number of rules decreases and vice versa.\nThe probability of the item Y being chosen when the item X selected is high.')
print('\nFrom the rules we can identify that there is 79% chance that when margarine, fruit/vegetable juicegurt and soda   are bought, whole milk are added into the basket.')
print('\nWhen bottled beer and root vegetables are bought there is 100% chance that whole milk is added into basket.')
printResults(items,rules)
# Out:
# Case 3 (minimum support = 0.001 and minimum confidence = 0.03)
#
# Case 3 Reasoning:
#
# In this minimum support value is decreased further to 0.1% and minimum confidence is decreased to 3%.
#
# As we further decrease the minimum support value the number of itemsets will be more. As the minumum confidence   value is decreased,the number of rules obtained increases considerably improves the possibility of an transaction of an item.
#
# Hence it can be said that as the confidence value increases, the number of rules decreases and vice versa.
# The probability of the item Y being chosen when the item X selected is high.
#
# From the rules we can identify that there is 79% chance that when margarine, fruit/vegetable juicegurt and soda   are bought, whole milk are added into the basket.
#
# When bottled beer and root vegetables are bought there is 100% chance that whole milk is added into basket.
#
# ------------ITEMS-----------------
# item: ('artif. sweetener"',) , 0.001
# ...

# %% [markdown]
# ### Task 3: Run FPgrowth and Evaluate Results

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth

# %%
df1
# Out:
#                                      itemDescription
# 0      sausage,whole milk,semi-finished bread,yogurt
# 1                      whole milk,pastry,salty snack
# 2                        canned beer,misc. beverages
# 3                           sausage,hygiene articles
# 4                            soda,pickled vegetables
# ...                                              ...
# 14958                            bottled water,herbs
# 14959                 semi-finished bread,newspapers
# 14960       soda,root vegetables,semi-finished bread
# 14961                  bottled beer,other vegetables
# 14962                   fruit/vegetable juice,onions
#
# [14963 rows x 1 columns]

# %%
data=open('dataset.csv')
read=csv.reader(data)
row=[]

# %%
data=open('dataset.csv')
read=csv.reader(data)
row=[]
for r in read:
    row.append(r)

# %%
final_row = []
for i in row:
    final_row.append(i[0].split(','))

# %%
te = TransactionEncoder()
te_ary = te.fit(final_row).transform(final_row)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 14959                  False     False             False             False
# 14960                  False     False             False             False
# 14961                  False     False             False             False
# 14962                  False     False             False             False
# 14963                  False     False             False             False
#
# ...

# %%
print ('# # # # # # # # #  Code for Task 3, Case:1 # # # # # # # # #') 
print ('\nCase 1 (minimum support=0.02)')
itemset=fpgrowth(df,min_support=0.02,use_colnames=True)
reasoning = "Here the minimum support is chosen to be 0.02 where we get around 37 rows in the itemset.\n"
reasoning += "For Example:\n"
reasoning += "The support value for whole milk around 0.157912, which means that chance of whole milk occuring in the dataset is around 15%.\n"
print (reasoning)
print('\nHere,minimum support is chosen as 2%, Minimum support is 2% because when we consider lower values for support the  chances of combination will increase more.')
#rule=association_rules(df, metric='confidence', min_threshold=0.8)print ('Case 1 Output:')
itemset
# Out:
# # # # # # # # # #  Code for Task 3, Case:1 # # # # # # # # #
#
# Case 1 (minimum support=0.02)
# Here the minimum support is chosen to be 0.02 where we get around 37 rows in the itemset.
# For Example:
# The support value for whole milk around 0.157912 which means that chance of whole milk occuring in the dataset is around 15%.
#
#
# Here,minimum support is chosen as 2%, Minimum support is 2% because when we consider lower values for support the  chances of combination will increase more.
#      support                 itemsets
# 0   0.157912             (whole milk)
# 1   0.085873                 (yogurt)
# 2   0.060345                (sausage)
# 3   0.051724                 (pastry)
# 4   0.046913            (canned beer)
# 5   0.097100                   (soda)
# 6   0.033948                   (beef)
# 7   0.023991            (white bread)
# 8   0.037757            (frankfurter)
# 9   0.033681                   (curd)
# 10  0.043705     (whipped/sour cream)
# ...

# %%
print ('# # # # # # # # #  Code for Task 3, Case:2 # # # # # # # # #') 
print ('\nCase 1 (minimum support=0.04)')
itemset1=fpgrowth(df,min_support=0.04,use_colnames=True)
# print ('Case 1 Reasoning:')
# print ('Case 1 Output:')

reasoning = "Here the minimum support is chosen to be 0.04 where we get around 15 rows in the itemset.\n"
reasoning += "For Example:\n"
reasoning += "The support value for yogurt around 0.0858 which means that chance of  Yogurt occuring in the dataset is   around 85%.\n"
reasoning += "When we increase the support value the chance of occurance of value in dataset is low."
print (reasoning)
print('\nHere,minimum support is chosen as 4%.')
#rule=association_rules(df, metric='confidence', min_threshold=0.8)print ('Case 1 Output:')
itemset


itemset1
# Out:
# # # # # # # # # #  Code for Task 3, Case:2 # # # # # # # # #
#
# Case 1 (minimum support=0.04)
# Here the minimum support is chosen to be 0.04 where we get around 15 rows in the itemset.
# For Example:
# The support value for yogurt around 0.0858 which means that chance of  Yogurt occuring in the dataset is   around 85%.
# When we increase the support value the chance of occurance of value in dataset is low.
#
# Here,minimum support is chosen as 4%.
#      support              itemsets
# 0   0.157912          (whole milk)
# 1   0.085873              (yogurt)
# 2   0.060345             (sausage)
# 3   0.051724              (pastry)
# 4   0.046913         (canned beer)
# 5   0.097100                (soda)
# 6   0.043705  (whipped/sour cream)
# 7   0.109997          (rolls/buns)
# 8   0.067763      (tropical fruit)
# 9   0.122093    (other vegetables)
# 10  0.069567     (root vegetables)
# 11  0.047581       (shopping bags)
# 12  0.049051           (pip fruit)
# ...

# %%
print ('# # # # # # # # #  Code for Task 3, Case:3 # # # # # # # # #') 
print ('\nCase 1 (minimum support=0.06)')
itemset3=fpgrowth(df,min_support=0.06,use_colnames=True)
reasoning = "Here the minimum support is chosen to be 0.06 where we get around 08 rows in the itemset.\n"
reasoning += "For Example:\n"
reasoning += "The support value for soda around 0.097100 which means that chance of soda occuring in the dataset is around 97%.\n"
reasoning += "When we keep on increasig the support value, the chances of occurance of value in datset is low."
print (reasoning)
print('\nHere,minimum support is chosen as 6%.')
itemset3
# Out:
# # # # # # # # # #  Code for Task 3, Case:3 # # # # # # # # #
#
# Case 1 (minimum support=0.06)
# Here the minimum support is chosen to be 0.06 where we get around 08 rows in the itemset.
# For Example:
# The support value for soda around 0.097100 which means that chance of soda occuring in the dataset is around 97%.
# When we keep on increasig the support value, the chances of occurance of value in datset is low.
#
# Here,minimum support is chosen as 6%.
#     support            itemsets
# 0  0.157912        (whole milk)
# 1  0.085873            (yogurt)
# 2  0.060345           (sausage)
# 3  0.097100              (soda)
# 4  0.109997        (rolls/buns)
# 5  0.067763    (tropical fruit)
# 6  0.122093  (other vegetables)
# 7  0.069567   (root vegetables)
# 8  0.060679     (bottled water)

# %% [markdown]
# ### References
#
# https://www.kaggle.com/acostasg/random-shopping-cart
#
# https://github.com/asaini/Apriori
#
# http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/fpgrowth/
#
# https://www.youtube.com/watch?v=Cryve9ZWbYk
